# %%
import pyforest

# %%
data = pd.read_csv("datasets_33080_43333_car data.csv")
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.2+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
data['Car_Age'] = 2020 - data['Year']

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age
# 0      Dealer       Manual      0        6
# 1      Dealer       Manual      0        7
# 2      Dealer       Manual      0        3
# 3      Dealer       Manual      0        9
# 4      Dealer       Manual      0        6

# %%
print(data['Seller_Type'].unique())
print(data['Fuel_Type'].unique())
print(data['Transmission'].unique())
print(data['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Petrol' 'Diesel' 'CNG']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
data['Car_Age'].describe()
# Out:
# count    301.000000
# mean       6.372093
# std        2.891554
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       17.000000
# Name: Car_Age, dtype: float64

# %%
data.loc[data['Car_Age'] == data['Car_Age'].max()]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 37      800  2003           0.35           2.28      127000    Petrol
# 39      sx4  2003           2.25           7.98       62000    Petrol
#
#    Seller_Type Transmission  Owner  Car_Age
# 37  Individual       Manual      0       17
# 39      Dealer       Manual      0       17

# %%
data.loc[data['Car_Age'] == data['Car_Age'].min()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age
# 5      Dealer       Manual      0        2

# %%
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      ritz  2014           3.35           5.59       27000    Petrol
# 30     ritz  2012           3.10           5.98       51439    Diesel
# 31     ritz  2011           2.35           4.89       54200    Petrol
# 46     ritz  2013           2.65           4.89       64532    Petrol
#
#    Seller_Type Transmission  Owner  Car_Age
# 0       Dealer       Manual      0        6
# 30      Dealer       Manual      0        8
# 31      Dealer       Manual      0        9
# 46      Dealer       Manual      0        7

# %%
car = data.groupby(['Car_Name','Year','Fuel_Type'])

# %%
car.first()
# Out:
#                                          Selling_Price  Present_Price  \
# Car_Name                 Year Fuel_Type
# 800                      2003 Petrol              0.35          2.280
# Activa 3g                2008 Petrol              0.17          0.520
#                          2016 Petrol              0.45          0.540
# Activa 4g                2017 Petrol              0.40          0.510
# Bajaj  ct 100            2015 Petrol              0.18          0.320
# Bajaj Avenger 150        2016 Petrol              0.75          0.800
# Bajaj Avenger 150 street 2016 Petrol              0.60          0.800
# Bajaj Avenger 220        2016 Petrol              0.72          0.950
#                          2017 Petrol              0.90          0.950
# Bajaj Avenger 220 dtsi   2010 Petrol              0.45          0.950
#                          2015 Petrol              0.60          0.950
# Bajaj Avenger Street 220 2011 Petrol              0.45          0.950
# ...
